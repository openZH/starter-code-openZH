# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Autogenerated Python starter code for data set with identifier* **690@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Archiv Wahlresultate Kantonsratswahlen**

# %% [markdown]
# ## Description
#
# Ergebnisse der Erneuerungswahlen der Mitglieder des Kantonsrates

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.html#/datasets/690@statistisches-amt-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2020-06-05T08:30:00`
# - **Modified** `2023-02-22T14:09:40`
# - **Startdate** `2007-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['kantonsrat', 'kantonsratswahlen', 'kanton_zuerich', 'panaschierstimmen', 'politik', 'politische_parteien', 'wahlen', 'wahlergebnisse', 'wahlarchiv', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/kantons-regierungsratswahlen.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`15` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3946
# Title                    : Panaschierstatistik Erneuerungswahl Kantonsrat 2023
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Kantonsratswahl 2023 pro Gemeinde
# Issued                   : 2023-02-21T09:37:19
# Modified                 : 2023-05-25T09:49:56
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00003946.csv')

# Distribution 1
# Ktzhdistid               : 3947
# Title                    : Kandidierende Erneuerungswahl Kantonsrat 2023
# Description              : Informationen zu den Kandidierenden der Kantonsratswahl 2023
# Issued                   : 2023-02-21T09:36:53
# Modified                 : 2023-05-25T14:27:05
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00003947.csv')

# Distribution 2
# Ktzhdistid               : 3948
# Title                    : Gemeindeinformationen Erneuerungswahl Kantonsrat 2023
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Kantonsratswahl 2023
# Issued                   : 2023-02-21T09:36:30
# Modified                 : 2023-05-25T09:50:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00003948.csv')

# Distribution 3
# Ktzhdistid               : 1666
# Title                    : Panaschierstatistik Erneuerungswahl Kantonsrat 2019
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Kantonsratswahl 2019 pro Gemeinde
# Issued                   : 2020-07-07T15:51:01
# Modified                 : 2023-02-13T14:00:09
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001666.csv')

# Distribution 4
# Ktzhdistid               : 1840
# Title                    : Kandidierende Erneuerungswahl Kantonsrat 2019
# Description              : Informationen zu den Kandidierenden der Kantonsratswahl 2019
# Issued                   : 2021-06-02T08:38:16
# Modified                 : 2023-02-13T14:00:24
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001840.csv')

# Distribution 5
# Ktzhdistid               : 1667
# Title                    : Gemeindeinformationen Erneuerungswahl Kantonsrat 2019
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Kantonsratswahl 2019
# Issued                   : 2020-07-07T15:51:21
# Modified                 : 2023-02-13T14:00:37
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001667.csv')

# Distribution 6
# Ktzhdistid               : 1664
# Title                    : Panaschierstatistik Erneuerungswahl Kantonsrat 2015
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Kantonsratswahl 2015 pro Gemeinde
# Issued                   : 2020-07-07T15:49:47
# Modified                 : 2023-02-13T14:00:45
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001664.csv')

# Distribution 7
# Ktzhdistid               : 1839
# Title                    : Kandidierende Erneuerungswahl Kantonsrat 2015
# Description              : Informationen zu den Kandidierenden der Kantonsratswahl 2015
# Issued                   : 2021-06-02T08:36:14
# Modified                 : 2023-02-13T14:00:54
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001839.csv')

# Distribution 8
# Ktzhdistid               : 1665
# Title                    : Gemeindeinformationen Erneuerungswahl Kantonsrat 2015
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Kantonsratswahl 2015
# Issued                   : 2020-07-07T15:50:09
# Modified                 : 2023-02-13T14:01:06
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001665.csv')

# Distribution 9
# Ktzhdistid               : 1662
# Title                    : Panaschierstatistik Erneuerungswahl Kantonsrat 2011
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Kantonsratswahl 2011 pro Gemeinde
# Issued                   : 2020-07-07T15:48:59
# Modified                 : 2023-02-13T14:01:19
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001662.csv')

# Distribution 10
# Ktzhdistid               : 1838
# Title                    : Kandidierende Erneuerungswahl Kantonsrat 2011
# Description              : Informationen zu den Kandidierenden der Kantonsratswahl 2011
# Issued                   : 2021-06-02T08:35:07
# Modified                 : 2023-02-13T14:01:29
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001838.csv')

# Distribution 11
# Ktzhdistid               : 1663
# Title                    : Gemeindeinformationen Erneuerungswahl Kantonsrat 2011
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Kantonsratswahl 2011
# Issued                   : 2020-07-07T15:49:26
# Modified                 : 2023-02-13T14:01:40
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001663.csv')

# Distribution 12
# Ktzhdistid               : 1660
# Title                    : Panaschierstatistik Erneuerungswahl Kantonsrat 2007
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Kantonsratswahl 2007 pro Gemeinde
# Issued                   : 2020-07-07T15:36:39
# Modified                 : 2023-02-13T14:01:52
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001660.csv')

# Distribution 13
# Ktzhdistid               : 1837
# Title                    : Kandidierende Erneuerungswahl Kantonsrat 2007
# Description              : Informationen zu den Kandidierenden der Kantonsratswahl 2007
# Issued                   : 2021-06-02T08:22:01
# Modified                 : 2023-02-13T14:02:02
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001837.csv')

# Distribution 14
# Ktzhdistid               : 1661
# Title                    : Gemeindeinformationen Erneuerungswahl Kantonsrat 2007
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Kantonsratswahl 2007
# Issued                   : 2020-07-07T15:44:54
# Modified                 : 2023-02-13T14:02:13
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000690_00001661.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch
