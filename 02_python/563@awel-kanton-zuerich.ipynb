# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Auto-generated Python starter code for dataset with identifier* **563@awel-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Lufttemperatur und Luftfeuchte LoRa-Sensor-Messwerte**

# %% [markdown]
# ## Description
#
# Seit Frühjahr 2019 betreibt das AWEL des Kantons Zürich ein Messnetz aus rund 40 Lufttemperatur und -feuchte Sensoren (LoRa). Die Sensor-Standorte befinden sich hauptsächlich im städtischen Raum, verdichtet in der Stadt Zürich, aber auch in weiteren Gemeinden im Kanton Zürich. Ziel des Messnetzes ist es, Messdaten für Stadtklima-Analysen bereitzustellen, damit Aspekte des Lokalklimas und Klimawandels stärker sichtbar werden und in der Raumplanung und Stadtentwicklung berücksichtigt werden können. Mit Hilfe dieser Daten lassen sich u.a. die Auswirkungen von Hitzewellen im städtischen Raum beschreiben. Das Messnetz wird durch das AWEL betrieben, unter Beteiligung der Stadt Zürich; die weiteren Standort-Gemeinden sind über die Messaktivität informiert.
# Der hier verfügbare Datensatz wird ab dem Jahr 2025 unregelmässig aktualisiert und umfasst alle, für die Standorte gültigen Messwerte im 10 Minuten Mittel, inklusive entsprechender Standortinformationen. Weitere Angaben zu Datensatz-Struktur und verwendeten Sensoren sind im Datensatz-Beschrieb zu finden.

# %% [markdown]
# ## Dataset links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/statistik-daten/datenkatalog.html#/datasets/563@awel-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2019-12-08T23:00:00`
# - **Modified** `2026-01-07T12:55:23`
# - **Startdate** `2026-01-01`
# - **Enddate** `2026-01-06`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/ENVI']`
# - **Keyword** `['luft', 'lufttemperaturen', 'ogd']`
# - **Publisher** `['Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich']`
# - **Landingpage** `nan`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'CSV' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`82` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1068
# Title                    : LoRa-Sensor-Messwerte 2020/03
# Description              : None
# Issued                   : 2022-03-09T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202003.csv')

# Distribution 1
# Ktzhdistid               : 1614
# Title                    : LoRa-Sensor-Messwerte 2020/02
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202002.csv')

# Distribution 2
# Ktzhdistid               : 1615
# Title                    : LoRa-Sensor-Messwerte 2020/01
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202001.csv')

# Distribution 3
# Ktzhdistid               : 1616
# Title                    : LoRa-Sensor-Messwerte 2019/12
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201912.csv')

# Distribution 4
# Ktzhdistid               : 1617
# Title                    : LoRa-Sensor-Messwerte 2019/11
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201911.csv')

# Distribution 5
# Ktzhdistid               : 1618
# Title                    : LoRa-Sensor-Messwerte 2019/10
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201910.csv')

# Distribution 6
# Ktzhdistid               : 1632
# Title                    : LoRa-Sensor-Messwerte 2020/05
# Description              : None
# Issued                   : 2020-05-03T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202005.csv')

# Distribution 7
# Ktzhdistid               : 1743
# Title                    : LoRa-Sensor-Messwerte 2020/11
# Description              : None
# Issued                   : 2020-11-01T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202011.csv')

# Distribution 8
# Ktzhdistid               : 1860
# Title                    : LoRa-Sensor-Messwerte 2021/07
# Description              : None
# Issued                   : 2021-07-12T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202107.csv')

# Distribution 9
# Ktzhdistid               : 1885
# Title                    : LoRa-Sensor-Messwerte 2021/10
# Description              : None
# Issued                   : 2021-10-03T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202110.csv')

# Distribution 10
# Ktzhdistid               : 1917
# Title                    : LoRa-Sensor-Messwerte 2021/11
# Description              : None
# Issued                   : 2021-11-09T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202111.csv')

# Distribution 11
# Ktzhdistid               : 2078
# Title                    : LoRa-Sensor-Messwerte 2022/01
# Description              : None
# Issued                   : 2022-01-13T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202201.csv')

# Distribution 12
# Ktzhdistid               : 2077
# Title                    : LoRa-Sensor-Messwerte 2021/12
# Description              : None
# Issued                   : 2022-01-13T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202112.csv')

# Distribution 13
# Ktzhdistid               : 1619
# Title                    : LoRa-Sensor-Messwerte 2019/09
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201909.csv')

# Distribution 14
# Ktzhdistid               : 1620
# Title                    : LoRa-Sensor-Messwerte 2019/08
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201908.csv')

# Distribution 15
# Ktzhdistid               : 1621
# Title                    : LoRa-Sensor-Messwerte 2019/07
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201907.csv')

# Distribution 16
# Ktzhdistid               : 1622
# Title                    : LoRa-Sensor-Messwerte 2019/06
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201906.csv')

# Distribution 17
# Ktzhdistid               : 1623
# Title                    : LoRa-Sensor-Messwerte 2019/05
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201905.csv')

# Distribution 18
# Ktzhdistid               : 1628
# Title                    : LoRa-Sensor-Messwerte 2020/04
# Description              : None
# Issued                   : 2020-04-08T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202004.csv')

# Distribution 19
# Ktzhdistid               : 1652
# Title                    : LoRa-Sensor-Messwerte 2020/06
# Description              : None
# Issued                   : 2020-06-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202006.csv')

# Distribution 20
# Ktzhdistid               : 1658
# Title                    : LoRa-Sensor-Messwerte 2020/07
# Description              : None
# Issued                   : 2020-07-05T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202007.csv')

# Distribution 21
# Ktzhdistid               : 1707
# Title                    : LoRa-Sensor-Messwerte 2020/08
# Description              : None
# Issued                   : 2020-08-02T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202008.csv')

# Distribution 22
# Ktzhdistid               : 1721
# Title                    : LoRa-Sensor-Messwerte 2020/09
# Description              : None
# Issued                   : 2020-09-07T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202009.csv')

# Distribution 23
# Ktzhdistid               : 1733
# Title                    : LoRa-Sensor-Messwerte 2020/10
# Description              : None
# Issued                   : 2020-10-04T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202010.csv')

# Distribution 24
# Ktzhdistid               : 1802
# Title                    : LoRa-Sensor-Messwerte 2021/04
# Description              : None
# Issued                   : 2021-04-06T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202104.csv')

# Distribution 25
# Ktzhdistid               : 1811
# Title                    : LoRa-Sensor-Messwerte 2021/05
# Description              : None
# Issued                   : 2021-05-02T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202105.csv')

# Distribution 26
# Ktzhdistid               : 1779
# Title                    : LoRa-Sensor-Messwerte 2020/12
# Description              : None
# Issued                   : 2021-01-10T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202012.csv')

# Distribution 27
# Ktzhdistid               : 1780
# Title                    : LoRa-Sensor-Messwerte 2021/01
# Description              : None
# Issued                   : 2021-01-10T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202101.csv')

# Distribution 28
# Ktzhdistid               : 1791
# Title                    : LoRa-Sensor-Messwerte 2021/03
# Description              : None
# Issued                   : 2021-03-02T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202103.csv')

# Distribution 29
# Ktzhdistid               : 1841
# Title                    : LoRa-Sensor-Messwerte 2021/06
# Description              : None
# Issued                   : 2021-06-03T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202106.csv')

# Distribution 30
# Ktzhdistid               : 1861
# Title                    : LoRa-Sensor-Messwerte 2021/08
# Description              : None
# Issued                   : 2021-08-18T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202108.csv')

# Distribution 31
# Ktzhdistid               : 1872
# Title                    : LoRa-Sensor-Messwerte 2021/09
# Description              : None
# Issued                   : 2021-09-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202109.csv')

# Distribution 32
# Ktzhdistid               : 1784
# Title                    : LoRa-Sensor-Messwerte 2021/02
# Description              : None
# Issued                   : 2021-01-31T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202102.csv')

# Distribution 33
# Ktzhdistid               : 2518
# Title                    : LoRa-Sensor-Messwerte 2022/04
# Description              : None
# Issued                   : 2022-04-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202204.csv')

# Distribution 34
# Ktzhdistid               : 3440
# Title                    : LoRa-Sensor-Messwerte 2022/11
# Description              : None
# Issued                   : 2022-11-01T23:00:00
# Modified                 : 2022-12-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202211.csv')

# Distribution 35
# Ktzhdistid               : 2198
# Title                    : LoRa-Sensor-Messwerte 2022/02
# Description              : None
# Issued                   : 2022-02-15T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202202.csv')

# Distribution 36
# Ktzhdistid               : 2959
# Title                    : LoRa-Sensor-Messwerte 2022/07
# Description              : None
# Issued                   : 2022-07-01T22:00:00
# Modified                 : 2022-08-25T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202207.csv')

# Distribution 37
# Ktzhdistid               : 3201
# Title                    : LoRa-Sensor-Messwerte 2019/04
# Description              : None
# Issued                   : 2022-08-24T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201904.csv')

# Distribution 38
# Ktzhdistid               : 3965
# Title                    : LoRa-Sensor-Messwerte 2023/02
# Description              : None
# Issued                   : 2023-02-15T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202302.csv')

# Distribution 39
# Ktzhdistid               : 3966
# Title                    : LoRa-Sensor-Messwerte 2023/01
# Description              : None
# Issued                   : 2023-02-15T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202301.csv')

# Distribution 40
# Ktzhdistid               : 4043
# Title                    : LoRa-Sensor-Messwerte 2023/03
# Description              : None
# Issued                   : 2023-03-01T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202303.csv')

# Distribution 41
# Ktzhdistid               : 4143
# Title                    : LoRa-Sensor-Messwerte 2023/04
# Description              : None
# Issued                   : 2023-04-01T22:00:00
# Modified                 : 2023-05-25T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202304.csv')

# Distribution 42
# Ktzhdistid               : 2362
# Title                    : LoRa-Sensor-Messwerte 2022/03
# Description              : None
# Issued                   : 2022-03-03T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202203.csv')

# Distribution 43
# Ktzhdistid               : 4203
# Title                    : LoRa-Sensor-Messwerte 2023/05
# Description              : None
# Issued                   : 2023-05-01T22:00:00
# Modified                 : 2023-06-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202305.csv')

# Distribution 44
# Ktzhdistid               : 4283
# Title                    : LoRa-Sensor-Messwerte 2023/06
# Description              : None
# Issued                   : 2023-06-01T22:00:00
# Modified                 : 2023-07-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202306.csv')

# Distribution 45
# Ktzhdistid               : 4363
# Title                    : LoRa-Sensor-Messwerte 2023/07
# Description              : None
# Issued                   : 2023-07-01T22:00:00
# Modified                 : 2023-08-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202307.csv')

# Distribution 46
# Ktzhdistid               : 4423
# Title                    : LoRa-Sensor-Messwerte 2023/08
# Description              : None
# Issued                   : 2023-08-01T22:00:00
# Modified                 : 2023-09-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202308.csv')

# Distribution 47
# Ktzhdistid               : 4503
# Title                    : LoRa-Sensor-Messwerte 2023/09
# Description              : None
# Issued                   : 2023-09-01T22:00:00
# Modified                 : 2023-10-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202309.csv')

# Distribution 48
# Ktzhdistid               : 4603
# Title                    : LoRa-Sensor-Messwerte 2023/10
# Description              : None
# Issued                   : 2023-10-01T22:00:00
# Modified                 : 2023-11-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202310.csv')

# Distribution 49
# Ktzhdistid               : 2638
# Title                    : LoRa-Sensor-Messwerte 2022/05
# Description              : None
# Issued                   : 2022-05-02T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202205.csv')

# Distribution 50
# Ktzhdistid               : 4745
# Title                    : LoRa-Sensor-Messwerte 2023/11
# Description              : None
# Issued                   : 2023-11-01T23:00:00
# Modified                 : 2023-12-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202311.csv')

# Distribution 51
# Ktzhdistid               : 2838
# Title                    : LoRa-Sensor-Messwerte 2022/06
# Description              : None
# Issued                   : 2022-06-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202206.csv')

# Distribution 52
# Ktzhdistid               : 4984
# Title                    : LoRa-Sensor-Messwerte 2023/12
# Description              : None
# Issued                   : 2023-12-01T23:00:00
# Modified                 : 2024-01-09T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202312.csv')

# Distribution 53
# Ktzhdistid               : 3120
# Title                    : LoRa-Sensor-Messwerte 2022/08
# Description              : None
# Issued                   : 2022-08-01T22:00:00
# Modified                 : 2022-09-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202208.csv')

# Distribution 54
# Ktzhdistid               : 5083
# Title                    : LoRa-Sensor-Messwerte 2024/01
# Description              : None
# Issued                   : 2024-01-01T23:00:00
# Modified                 : 2024-02-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202401.csv')

# Distribution 55
# Ktzhdistid               : 3240
# Title                    : LoRa-Sensor-Messwerte 2022/09
# Description              : None
# Issued                   : 2022-09-01T22:00:00
# Modified                 : 2022-10-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202209.csv')

# Distribution 56
# Ktzhdistid               : 5163
# Title                    : LoRa-Sensor-Messwerte 2024/02
# Description              : None
# Issued                   : 2024-02-01T23:00:00
# Modified                 : 2024-03-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202402.csv')

# Distribution 57
# Ktzhdistid               : 3340
# Title                    : LoRa-Sensor-Messwerte 2022/10
# Description              : None
# Issued                   : 2022-10-01T22:00:00
# Modified                 : 2022-11-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202210.csv')

# Distribution 58
# Ktzhdistid               : 5228
# Title                    : LoRa-Sensor-Messwerte 2024/03
# Description              : None
# Issued                   : 2024-03-01T23:00:00
# Modified                 : 2024-04-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202403.csv')

# Distribution 59
# Ktzhdistid               : 3660
# Title                    : LoRa-Sensor-Messwerte 2022/12
# Description              : None
# Issued                   : 2022-12-01T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202212.csv')

# Distribution 60
# Ktzhdistid               : 5263
# Title                    : LoRa-Sensor-Messwerte 2024/04
# Description              : None
# Issued                   : 2024-04-01T22:00:00
# Modified                 : 2024-06-30T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202404.csv')

# Distribution 61
# Ktzhdistid               : 5343
# Title                    : LoRa-Sensor-Messwerte 2024/05
# Description              : None
# Issued                   : 2024-05-01T22:00:00
# Modified                 : 2024-06-30T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202405.csv')

# Distribution 62
# Ktzhdistid               : 5383
# Title                    : LoRa-Sensor-Messwerte 2024/06
# Description              : None
# Issued                   : 2024-06-01T22:00:00
# Modified                 : 2024-07-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202406.csv')

# Distribution 63
# Ktzhdistid               : 5423
# Title                    : LoRa-Sensor-Messwerte 2024/07
# Description              : None
# Issued                   : 2024-07-01T22:00:00
# Modified                 : 2024-08-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202407.csv')

# Distribution 64
# Ktzhdistid               : 5483
# Title                    : LoRa-Sensor-Messwerte 2024/08
# Description              : None
# Issued                   : 2024-08-01T22:00:00
# Modified                 : 2024-09-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202408.csv')

# Distribution 65
# Ktzhdistid               : 5543
# Title                    : LoRa-Sensor-Messwerte 2024/09
# Description              : None
# Issued                   : 2024-09-01T22:00:00
# Modified                 : 2024-10-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202409.csv')

# Distribution 66
# Ktzhdistid               : 5563
# Title                    : LoRa-Sensor-Messwerte 2024/10
# Description              : None
# Issued                   : 2024-10-01T22:00:00
# Modified                 : 2024-11-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202410.csv')

# Distribution 67
# Ktzhdistid               : 5643
# Title                    : LoRa-Sensor-Messwerte 2024/11
# Description              : None
# Issued                   : 2024-11-01T23:00:00
# Modified                 : 2024-12-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202411.csv')

# Distribution 68
# Ktzhdistid               : 5763
# Title                    : LoRa-Sensor-Messwerte 2024/12
# Description              : None
# Issued                   : 2024-12-01T23:00:00
# Modified                 : 2025-01-30T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202412.csv')

# Distribution 69
# Ktzhdistid               : 5923
# Title                    : LoRa-Sensor-Messwerte 2025/01
# Description              : None
# Issued                   : 2025-01-30T23:00:00
# Modified                 : 2025-01-30T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202501.csv')

# Distribution 70
# Ktzhdistid               : 6143
# Title                    : LoRa-Sensor-Messwerte 2025/02
# Description              : None
# Issued                   : 2025-04-08T22:00:00
# Modified                 : 2025-04-08T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202502.csv')

# Distribution 71
# Ktzhdistid               : 6144
# Title                    : LoRa-Sensor-Messwerte 2025/03
# Description              : None
# Issued                   : 2025-04-08T22:00:00
# Modified                 : 2025-04-08T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202503.csv')

# Distribution 72
# Ktzhdistid               : 6145
# Title                    : LoRa-Sensor-Messwerte 2025/04
# Description              : None
# Issued                   : 2025-04-08T22:00:00
# Modified                 : 2025-08-06T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202504.csv')

# Distribution 73
# Ktzhdistid               : 6443
# Title                    : LoRa-Sensor-Messwerte 2025/05
# Description              : None
# Issued                   : 2025-07-22T22:00:00
# Modified                 : 2025-07-22T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202505.csv')

# Distribution 74
# Ktzhdistid               : 6444
# Title                    : LoRa-Sensor-Messwerte 2025/06
# Description              : None
# Issued                   : 2025-07-22T22:00:00
# Modified                 : 2025-08-06T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202506.csv')

# Distribution 75
# Ktzhdistid               : 6445
# Title                    : LoRa-Sensor-Messwerte 2025/07
# Description              : None
# Issued                   : 2025-07-22T22:00:00
# Modified                 : 2025-12-18T10:30:49

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202507.csv')

# Distribution 76
# Ktzhdistid               : 6523
# Title                    : LoRa-Sensor-Messwerte 2025/08
# Description              : None
# Issued                   : 2025-08-06T22:00:00
# Modified                 : 2025-12-18T10:32:03

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202508.csv')

# Distribution 77
# Ktzhdistid               : 6723
# Title                    : LoRa-Sensor-Messwerte 2025/09
# Description              : None
# Issued                   : 2025-12-18T12:49:13
# Modified                 : 2025-12-18T12:49:13

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202509.csv')

# Distribution 78
# Ktzhdistid               : 6724
# Title                    : LoRa-Sensor-Messwerte 2025/10
# Description              : None
# Issued                   : 2025-12-18T12:55:48
# Modified                 : 2025-12-18T12:55:48

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202510.csv')

# Distribution 79
# Ktzhdistid               : 6725
# Title                    : LoRa-Sensor-Messwerte 2025/11
# Description              : None
# Issued                   : 2025-12-18T12:56:15
# Modified                 : 2025-12-18T12:56:15

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202511.csv')

# Distribution 80
# Ktzhdistid               : 6726
# Title                    : LoRa-Sensor-Messwerte 2025/12
# Description              : None
# Issued                   : 2025-12-18T12:56:43
# Modified                 : 2026-01-07T12:55:05

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202512.csv')

# Distribution 81
# Ktzhdistid               : 6731
# Title                    : LoRa-Sensor-Messwerte 2026/01
# Description              : None
# Issued                   : 2026-01-07T12:55:20
# Modified                 : 2026-01-07T12:55:20

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202601.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except Exception:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except Exception:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except Exception:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Questions about the data?** Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich | Abteilung Luft, Klima und Strahlung | joerg.sintermann@bd.zh.ch

# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Auto-generated Python starter code for dataset with identifier* **563@awel-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Lufttemperatur und Luftfeuchte LoRa-Sensor-Messwerte**

# %% [markdown]
# ## Description
#
# Seit Frühjahr 2019 betreibt das AWEL des Kantons Zürich ein Messnetz aus rund 40 Lufttemperatur und -feuchte Sensoren (LoRa). Die Sensor-Standorte befinden sich hauptsächlich im städtischen Raum, verdichtet in der Stadt Zürich, aber auch in weiteren Gemeinden im Kanton Zürich. Ziel des Messnetzes ist es, Messdaten für Stadtklima-Analysen bereitzustellen, damit Aspekte des Lokalklimas und Klimawandels stärker sichtbar werden und in der Raumplanung und Stadtentwicklung berücksichtigt werden können. Mit Hilfe dieser Daten lassen sich u.a. die Auswirkungen von Hitzewellen im städtischen Raum beschreiben. Das Messnetz wird durch das AWEL betrieben, unter Beteiligung der Stadt Zürich; die weiteren Standort-Gemeinden sind über die Messaktivität informiert.
# Der hier verfügbare Datensatz wird ab dem Jahr 2025 unregelmässig aktualisiert und umfasst alle, für die Standorte gültigen Messwerte im 10 Minuten Mittel, inklusive entsprechender Standortinformationen. Weitere Angaben zu Datensatz-Struktur und verwendeten Sensoren sind im Datensatz-Beschrieb zu finden.

# %% [markdown]
# ## Dataset links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/statistik-daten/datenkatalog.html#/datasets/563@awel-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2019-12-08T23:00:00`
# - **Modified** `2026-01-07T12:55:23`
# - **Startdate** `2026-01-01`
# - **Enddate** `2026-01-06`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/ENVI']`
# - **Keyword** `['luft', 'lufttemperaturen', 'ogd']`
# - **Publisher** `['Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich']`
# - **Landingpage** `nan`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'CSV' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`82` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1068
# Title                    : LoRa-Sensor-Messwerte 2020/03
# Description              : None
# Issued                   : 2022-03-09T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202003.csv')

# Distribution 1
# Ktzhdistid               : 1614
# Title                    : LoRa-Sensor-Messwerte 2020/02
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202002.csv')

# Distribution 2
# Ktzhdistid               : 1615
# Title                    : LoRa-Sensor-Messwerte 2020/01
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202001.csv')

# Distribution 3
# Ktzhdistid               : 1616
# Title                    : LoRa-Sensor-Messwerte 2019/12
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201912.csv')

# Distribution 4
# Ktzhdistid               : 1617
# Title                    : LoRa-Sensor-Messwerte 2019/11
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201911.csv')

# Distribution 5
# Ktzhdistid               : 1618
# Title                    : LoRa-Sensor-Messwerte 2019/10
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201910.csv')

# Distribution 6
# Ktzhdistid               : 1632
# Title                    : LoRa-Sensor-Messwerte 2020/05
# Description              : None
# Issued                   : 2020-05-03T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202005.csv')

# Distribution 7
# Ktzhdistid               : 1743
# Title                    : LoRa-Sensor-Messwerte 2020/11
# Description              : None
# Issued                   : 2020-11-01T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202011.csv')

# Distribution 8
# Ktzhdistid               : 1860
# Title                    : LoRa-Sensor-Messwerte 2021/07
# Description              : None
# Issued                   : 2021-07-12T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202107.csv')

# Distribution 9
# Ktzhdistid               : 1885
# Title                    : LoRa-Sensor-Messwerte 2021/10
# Description              : None
# Issued                   : 2021-10-03T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202110.csv')

# Distribution 10
# Ktzhdistid               : 1917
# Title                    : LoRa-Sensor-Messwerte 2021/11
# Description              : None
# Issued                   : 2021-11-09T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202111.csv')

# Distribution 11
# Ktzhdistid               : 2078
# Title                    : LoRa-Sensor-Messwerte 2022/01
# Description              : None
# Issued                   : 2022-01-13T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202201.csv')

# Distribution 12
# Ktzhdistid               : 2077
# Title                    : LoRa-Sensor-Messwerte 2021/12
# Description              : None
# Issued                   : 2022-01-13T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202112.csv')

# Distribution 13
# Ktzhdistid               : 1619
# Title                    : LoRa-Sensor-Messwerte 2019/09
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201909.csv')

# Distribution 14
# Ktzhdistid               : 1620
# Title                    : LoRa-Sensor-Messwerte 2019/08
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201908.csv')

# Distribution 15
# Ktzhdistid               : 1621
# Title                    : LoRa-Sensor-Messwerte 2019/07
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201907.csv')

# Distribution 16
# Ktzhdistid               : 1622
# Title                    : LoRa-Sensor-Messwerte 2019/06
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201906.csv')

# Distribution 17
# Ktzhdistid               : 1623
# Title                    : LoRa-Sensor-Messwerte 2019/05
# Description              : None
# Issued                   : 2020-03-05T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201905.csv')

# Distribution 18
# Ktzhdistid               : 1628
# Title                    : LoRa-Sensor-Messwerte 2020/04
# Description              : None
# Issued                   : 2020-04-08T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202004.csv')

# Distribution 19
# Ktzhdistid               : 1652
# Title                    : LoRa-Sensor-Messwerte 2020/06
# Description              : None
# Issued                   : 2020-06-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202006.csv')

# Distribution 20
# Ktzhdistid               : 1658
# Title                    : LoRa-Sensor-Messwerte 2020/07
# Description              : None
# Issued                   : 2020-07-05T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202007.csv')

# Distribution 21
# Ktzhdistid               : 1707
# Title                    : LoRa-Sensor-Messwerte 2020/08
# Description              : None
# Issued                   : 2020-08-02T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202008.csv')

# Distribution 22
# Ktzhdistid               : 1721
# Title                    : LoRa-Sensor-Messwerte 2020/09
# Description              : None
# Issued                   : 2020-09-07T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202009.csv')

# Distribution 23
# Ktzhdistid               : 1733
# Title                    : LoRa-Sensor-Messwerte 2020/10
# Description              : None
# Issued                   : 2020-10-04T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202010.csv')

# Distribution 24
# Ktzhdistid               : 1802
# Title                    : LoRa-Sensor-Messwerte 2021/04
# Description              : None
# Issued                   : 2021-04-06T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202104.csv')

# Distribution 25
# Ktzhdistid               : 1811
# Title                    : LoRa-Sensor-Messwerte 2021/05
# Description              : None
# Issued                   : 2021-05-02T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202105.csv')

# Distribution 26
# Ktzhdistid               : 1779
# Title                    : LoRa-Sensor-Messwerte 2020/12
# Description              : None
# Issued                   : 2021-01-10T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202012.csv')

# Distribution 27
# Ktzhdistid               : 1780
# Title                    : LoRa-Sensor-Messwerte 2021/01
# Description              : None
# Issued                   : 2021-01-10T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202101.csv')

# Distribution 28
# Ktzhdistid               : 1791
# Title                    : LoRa-Sensor-Messwerte 2021/03
# Description              : None
# Issued                   : 2021-03-02T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202103.csv')

# Distribution 29
# Ktzhdistid               : 1841
# Title                    : LoRa-Sensor-Messwerte 2021/06
# Description              : None
# Issued                   : 2021-06-03T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202106.csv')

# Distribution 30
# Ktzhdistid               : 1861
# Title                    : LoRa-Sensor-Messwerte 2021/08
# Description              : None
# Issued                   : 2021-08-18T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202108.csv')

# Distribution 31
# Ktzhdistid               : 1872
# Title                    : LoRa-Sensor-Messwerte 2021/09
# Description              : None
# Issued                   : 2021-09-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202109.csv')

# Distribution 32
# Ktzhdistid               : 1784
# Title                    : LoRa-Sensor-Messwerte 2021/02
# Description              : None
# Issued                   : 2021-01-31T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202102.csv')

# Distribution 33
# Ktzhdistid               : 2518
# Title                    : LoRa-Sensor-Messwerte 2022/04
# Description              : None
# Issued                   : 2022-04-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202204.csv')

# Distribution 34
# Ktzhdistid               : 3440
# Title                    : LoRa-Sensor-Messwerte 2022/11
# Description              : None
# Issued                   : 2022-11-01T23:00:00
# Modified                 : 2022-12-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202211.csv')

# Distribution 35
# Ktzhdistid               : 2198
# Title                    : LoRa-Sensor-Messwerte 2022/02
# Description              : None
# Issued                   : 2022-02-15T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202202.csv')

# Distribution 36
# Ktzhdistid               : 2959
# Title                    : LoRa-Sensor-Messwerte 2022/07
# Description              : None
# Issued                   : 2022-07-01T22:00:00
# Modified                 : 2022-08-25T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202207.csv')

# Distribution 37
# Ktzhdistid               : 3201
# Title                    : LoRa-Sensor-Messwerte 2019/04
# Description              : None
# Issued                   : 2022-08-24T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_201904.csv')

# Distribution 38
# Ktzhdistid               : 3965
# Title                    : LoRa-Sensor-Messwerte 2023/02
# Description              : None
# Issued                   : 2023-02-15T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202302.csv')

# Distribution 39
# Ktzhdistid               : 3966
# Title                    : LoRa-Sensor-Messwerte 2023/01
# Description              : None
# Issued                   : 2023-02-15T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202301.csv')

# Distribution 40
# Ktzhdistid               : 4043
# Title                    : LoRa-Sensor-Messwerte 2023/03
# Description              : None
# Issued                   : 2023-03-01T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202303.csv')

# Distribution 41
# Ktzhdistid               : 4143
# Title                    : LoRa-Sensor-Messwerte 2023/04
# Description              : None
# Issued                   : 2023-04-01T22:00:00
# Modified                 : 2023-05-25T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202304.csv')

# Distribution 42
# Ktzhdistid               : 2362
# Title                    : LoRa-Sensor-Messwerte 2022/03
# Description              : None
# Issued                   : 2022-03-03T23:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202203.csv')

# Distribution 43
# Ktzhdistid               : 4203
# Title                    : LoRa-Sensor-Messwerte 2023/05
# Description              : None
# Issued                   : 2023-05-01T22:00:00
# Modified                 : 2023-06-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202305.csv')

# Distribution 44
# Ktzhdistid               : 4283
# Title                    : LoRa-Sensor-Messwerte 2023/06
# Description              : None
# Issued                   : 2023-06-01T22:00:00
# Modified                 : 2023-07-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202306.csv')

# Distribution 45
# Ktzhdistid               : 4363
# Title                    : LoRa-Sensor-Messwerte 2023/07
# Description              : None
# Issued                   : 2023-07-01T22:00:00
# Modified                 : 2023-08-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202307.csv')

# Distribution 46
# Ktzhdistid               : 4423
# Title                    : LoRa-Sensor-Messwerte 2023/08
# Description              : None
# Issued                   : 2023-08-01T22:00:00
# Modified                 : 2023-09-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202308.csv')

# Distribution 47
# Ktzhdistid               : 4503
# Title                    : LoRa-Sensor-Messwerte 2023/09
# Description              : None
# Issued                   : 2023-09-01T22:00:00
# Modified                 : 2023-10-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202309.csv')

# Distribution 48
# Ktzhdistid               : 4603
# Title                    : LoRa-Sensor-Messwerte 2023/10
# Description              : None
# Issued                   : 2023-10-01T22:00:00
# Modified                 : 2023-11-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202310.csv')

# Distribution 49
# Ktzhdistid               : 2638
# Title                    : LoRa-Sensor-Messwerte 2022/05
# Description              : None
# Issued                   : 2022-05-02T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202205.csv')

# Distribution 50
# Ktzhdistid               : 4745
# Title                    : LoRa-Sensor-Messwerte 2023/11
# Description              : None
# Issued                   : 2023-11-01T23:00:00
# Modified                 : 2023-12-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202311.csv')

# Distribution 51
# Ktzhdistid               : 2838
# Title                    : LoRa-Sensor-Messwerte 2022/06
# Description              : None
# Issued                   : 2022-06-01T22:00:00
# Modified                 : 2022-08-24T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202206.csv')

# Distribution 52
# Ktzhdistid               : 4984
# Title                    : LoRa-Sensor-Messwerte 2023/12
# Description              : None
# Issued                   : 2023-12-01T23:00:00
# Modified                 : 2024-01-09T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202312.csv')

# Distribution 53
# Ktzhdistid               : 3120
# Title                    : LoRa-Sensor-Messwerte 2022/08
# Description              : None
# Issued                   : 2022-08-01T22:00:00
# Modified                 : 2022-09-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202208.csv')

# Distribution 54
# Ktzhdistid               : 5083
# Title                    : LoRa-Sensor-Messwerte 2024/01
# Description              : None
# Issued                   : 2024-01-01T23:00:00
# Modified                 : 2024-02-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202401.csv')

# Distribution 55
# Ktzhdistid               : 3240
# Title                    : LoRa-Sensor-Messwerte 2022/09
# Description              : None
# Issued                   : 2022-09-01T22:00:00
# Modified                 : 2022-10-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202209.csv')

# Distribution 56
# Ktzhdistid               : 5163
# Title                    : LoRa-Sensor-Messwerte 2024/02
# Description              : None
# Issued                   : 2024-02-01T23:00:00
# Modified                 : 2024-03-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202402.csv')

# Distribution 57
# Ktzhdistid               : 3340
# Title                    : LoRa-Sensor-Messwerte 2022/10
# Description              : None
# Issued                   : 2022-10-01T22:00:00
# Modified                 : 2022-11-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202210.csv')

# Distribution 58
# Ktzhdistid               : 5228
# Title                    : LoRa-Sensor-Messwerte 2024/03
# Description              : None
# Issued                   : 2024-03-01T23:00:00
# Modified                 : 2024-04-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202403.csv')

# Distribution 59
# Ktzhdistid               : 3660
# Title                    : LoRa-Sensor-Messwerte 2022/12
# Description              : None
# Issued                   : 2022-12-01T23:00:00
# Modified                 : 2023-04-26T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202212.csv')

# Distribution 60
# Ktzhdistid               : 5263
# Title                    : LoRa-Sensor-Messwerte 2024/04
# Description              : None
# Issued                   : 2024-04-01T22:00:00
# Modified                 : 2024-06-30T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202404.csv')

# Distribution 61
# Ktzhdistid               : 5343
# Title                    : LoRa-Sensor-Messwerte 2024/05
# Description              : None
# Issued                   : 2024-05-01T22:00:00
# Modified                 : 2024-06-30T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202405.csv')

# Distribution 62
# Ktzhdistid               : 5383
# Title                    : LoRa-Sensor-Messwerte 2024/06
# Description              : None
# Issued                   : 2024-06-01T22:00:00
# Modified                 : 2024-07-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202406.csv')

# Distribution 63
# Ktzhdistid               : 5423
# Title                    : LoRa-Sensor-Messwerte 2024/07
# Description              : None
# Issued                   : 2024-07-01T22:00:00
# Modified                 : 2024-08-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202407.csv')

# Distribution 64
# Ktzhdistid               : 5483
# Title                    : LoRa-Sensor-Messwerte 2024/08
# Description              : None
# Issued                   : 2024-08-01T22:00:00
# Modified                 : 2024-09-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202408.csv')

# Distribution 65
# Ktzhdistid               : 5543
# Title                    : LoRa-Sensor-Messwerte 2024/09
# Description              : None
# Issued                   : 2024-09-01T22:00:00
# Modified                 : 2024-10-01T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202409.csv')

# Distribution 66
# Ktzhdistid               : 5563
# Title                    : LoRa-Sensor-Messwerte 2024/10
# Description              : None
# Issued                   : 2024-10-01T22:00:00
# Modified                 : 2024-11-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202410.csv')

# Distribution 67
# Ktzhdistid               : 5643
# Title                    : LoRa-Sensor-Messwerte 2024/11
# Description              : None
# Issued                   : 2024-11-01T23:00:00
# Modified                 : 2024-12-01T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202411.csv')

# Distribution 68
# Ktzhdistid               : 5763
# Title                    : LoRa-Sensor-Messwerte 2024/12
# Description              : None
# Issued                   : 2024-12-01T23:00:00
# Modified                 : 2025-01-30T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202412.csv')

# Distribution 69
# Ktzhdistid               : 5923
# Title                    : LoRa-Sensor-Messwerte 2025/01
# Description              : None
# Issued                   : 2025-01-30T23:00:00
# Modified                 : 2025-01-30T23:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202501.csv')

# Distribution 70
# Ktzhdistid               : 6143
# Title                    : LoRa-Sensor-Messwerte 2025/02
# Description              : None
# Issued                   : 2025-04-08T22:00:00
# Modified                 : 2025-04-08T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202502.csv')

# Distribution 71
# Ktzhdistid               : 6144
# Title                    : LoRa-Sensor-Messwerte 2025/03
# Description              : None
# Issued                   : 2025-04-08T22:00:00
# Modified                 : 2025-04-08T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202503.csv')

# Distribution 72
# Ktzhdistid               : 6145
# Title                    : LoRa-Sensor-Messwerte 2025/04
# Description              : None
# Issued                   : 2025-04-08T22:00:00
# Modified                 : 2025-08-06T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202504.csv')

# Distribution 73
# Ktzhdistid               : 6443
# Title                    : LoRa-Sensor-Messwerte 2025/05
# Description              : None
# Issued                   : 2025-07-22T22:00:00
# Modified                 : 2025-07-22T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202505.csv')

# Distribution 74
# Ktzhdistid               : 6444
# Title                    : LoRa-Sensor-Messwerte 2025/06
# Description              : None
# Issued                   : 2025-07-22T22:00:00
# Modified                 : 2025-08-06T22:00:00

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202506.csv')

# Distribution 75
# Ktzhdistid               : 6445
# Title                    : LoRa-Sensor-Messwerte 2025/07
# Description              : None
# Issued                   : 2025-07-22T22:00:00
# Modified                 : 2025-12-18T10:30:49

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202507.csv')

# Distribution 76
# Ktzhdistid               : 6523
# Title                    : LoRa-Sensor-Messwerte 2025/08
# Description              : None
# Issued                   : 2025-08-06T22:00:00
# Modified                 : 2025-12-18T10:32:03

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202508.csv')

# Distribution 77
# Ktzhdistid               : 6723
# Title                    : LoRa-Sensor-Messwerte 2025/09
# Description              : None
# Issued                   : 2025-12-18T12:49:13
# Modified                 : 2025-12-18T12:49:13

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202509.csv')

# Distribution 78
# Ktzhdistid               : 6724
# Title                    : LoRa-Sensor-Messwerte 2025/10
# Description              : None
# Issued                   : 2025-12-18T12:55:48
# Modified                 : 2025-12-18T12:55:48

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202510.csv')

# Distribution 79
# Ktzhdistid               : 6725
# Title                    : LoRa-Sensor-Messwerte 2025/11
# Description              : None
# Issued                   : 2025-12-18T12:56:15
# Modified                 : 2025-12-18T12:56:15

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202511.csv')

# Distribution 80
# Ktzhdistid               : 6726
# Title                    : LoRa-Sensor-Messwerte 2025/12
# Description              : None
# Issued                   : 2025-12-18T12:56:43
# Modified                 : 2026-01-07T12:55:05

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202512.csv')

# Distribution 81
# Ktzhdistid               : 6731
# Title                    : LoRa-Sensor-Messwerte 2026/01
# Description              : None
# Issued                   : 2026-01-07T12:55:20
# Modified                 : 2026-01-07T12:55:20

df = get_dataset('https://www.web.statistik.zh.ch/awel/LoRa/data/AWEL_Sensors_LoRa_202601.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Questions about the data?** Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich | Abteilung Luft, Klima und Strahlung | joerg.sintermann@bd.zh.ch
