# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Autogenerated Python starter code for data set with identifier* **694@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Archiv Wahlresultate Regierungsratswahlen**

# %% [markdown]
# ## Description
#
# Ergebnisse der Erneuerungs- und Ersatzwahlen der Mitglieder des Regierungsrates

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.html#/datasets/694@statistisches-amt-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2020-07-07T16:39:00`
# - **Modified** `2023-02-13T13:54:59`
# - **Startdate** `2007-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['kanton_zuerich', 'politik', 'politische_parteien', 'regierungsrat', 'regierungsratswahlen', 'wahlen', 'wahlergebnisse', 'wahlarchiv', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/kantons-regierungsratswahlen.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`12` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3944
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2023
# Description              : None
# Issued                   : 2023-02-21T10:11:45
# Modified                 : 2023-05-25T17:04:11
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00003944.csv')

# Distribution 1
# Ktzhdistid               : 3945
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2023
# Description              : None
# Issued                   : 2023-02-21T10:06:02
# Modified                 : 2023-05-26T08:36:43
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00003945.csv')

# Distribution 2
# Ktzhdistid               : 1690
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2019
# Description              : None
# Issued                   : 2020-07-07T16:46:50
# Modified                 : 2023-02-13T13:55:50
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001690.csv')

# Distribution 3
# Ktzhdistid               : 1830
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2019
# Description              : None
# Issued                   : 2021-06-01T13:47:09
# Modified                 : 2023-02-13T13:56:00
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001830.csv')

# Distribution 4
# Ktzhdistid               : 1689
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2015
# Description              : None
# Issued                   : 2020-07-07T16:46:18
# Modified                 : 2023-02-13T13:56:12
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001689.csv')

# Distribution 5
# Ktzhdistid               : 1829
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2015
# Description              : None
# Issued                   : 2021-06-01T13:43:00
# Modified                 : 2023-02-13T14:07:53
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001829.csv')

# Distribution 6
# Ktzhdistid               : 1688
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2011
# Description              : None
# Issued                   : 2020-07-07T16:45:23
# Modified                 : 2023-02-13T14:07:38
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001688.csv')

# Distribution 7
# Ktzhdistid               : 1828
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2011
# Description              : None
# Issued                   : 2021-06-01T13:38:41
# Modified                 : 2023-02-13T14:07:27
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001828.csv')

# Distribution 8
# Ktzhdistid               : 1737
# Title                    : Resultate 1. Wahlgang Ersatzwahl Regierungsrat 2009
# Description              : None
# Issued                   : 2020-10-09T11:38:54
# Modified                 : 2023-02-13T14:07:15
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001737.csv')

# Distribution 9
# Ktzhdistid               : 1827
# Title                    : Kandidierende 1. Wahlgang Ersatzwahl Regierungsrat 2009
# Description              : None
# Issued                   : 2021-06-01T13:37:41
# Modified                 : 2023-02-13T14:07:04
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001827.csv')

# Distribution 10
# Ktzhdistid               : 1687
# Title                    : Resultate 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2007
# Description              : None
# Issued                   : 2020-07-07T16:44:16
# Modified                 : 2023-02-13T14:06:52
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001687.csv')

# Distribution 11
# Ktzhdistid               : 1826
# Title                    : Kandidierende 1. Wahlgang Gesamterneuerungswahl Regierungsrat 2007
# Description              : None
# Issued                   : 2021-06-01T13:36:34
# Modified                 : 2023-02-13T14:06:42
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceNotRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000694_00001826.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch
