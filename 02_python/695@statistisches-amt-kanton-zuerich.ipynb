# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Autogenerated Python starter code for data set with identifier* **695@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Archiv Wahlresultate Ständeratswahlen**

# %% [markdown]
# ## Description
#
# Ergebnisse der Erneuerungswahlen der zürcherischen Mitglieder des Ständerates

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.html#/datasets/695@statistisches-amt-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2020-07-07T16:48:00`
# - **Modified** `2023-01-04T14:12:58`
# - **Startdate** `2003-12-31`
# - **Enddate** `2019-12-31`
# - **Theme** `['Politik']`
# - **Keyword** `['kanton_zuerich', 'politik', 'politische_parteien', 'staenderat', 'staenderatswahlen', 'wahlen', 'wahlergebnisse', 'wahlarchiv', 'demokratie', 'ogd']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/national-staenderatswahlen.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`18` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1700
# Title                    : Resultate 2. Wahlgang Erneuerungswahl Ständerat 2019
# Description              : None
# Issued                   : 2020-07-07T17:02:14
# Modified                 : 2021-06-01T13:24:45
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001700.csv')

# Distribution 1
# Ktzhdistid               : 1825
# Title                    : Kandidierende 2. Wahlgang Erneuerungswahl Ständerat 2019
# Description              : None
# Issued                   : 2021-06-01T13:10:50
# Modified                 : 2021-06-01T13:24:57
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001825.csv')

# Distribution 2
# Ktzhdistid               : 1699
# Title                    : Resultate 1. Wahlgang Erneuerungswahl Ständerat 2019
# Description              : None
# Issued                   : 2020-07-07T17:01:28
# Modified                 : 2021-06-01T13:24:25
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001699.csv')

# Distribution 3
# Ktzhdistid               : 1824
# Title                    : Kandidierende 1. Wahlgang Erneuerungswahl Ständerat 2019
# Description              : None
# Issued                   : 2021-06-01T13:07:24
# Modified                 : 2021-06-01T13:24:35
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001824.csv')

# Distribution 4
# Ktzhdistid               : 1698
# Title                    : Resultate 2. Wahlgang Erneuerungswahl Ständerat 2015
# Description              : None
# Issued                   : 2020-07-07T17:01:08
# Modified                 : 2021-06-01T13:23:18
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001698.csv')

# Distribution 5
# Ktzhdistid               : 1823
# Title                    : Kandidierende 2. Wahlgang Erneuerungswahl Ständerat 2015
# Description              : None
# Issued                   : 2021-06-01T13:03:51
# Modified                 : 2021-06-01T13:24:01
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001823.csv')

# Distribution 6
# Ktzhdistid               : 1697
# Title                    : Resultate 1. Wahlgang Erneuerungswahl Ständerat 2015
# Description              : None
# Issued                   : 2020-07-07T17:00:45
# Modified                 : 2021-06-01T13:01:04
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001697.csv')

# Distribution 7
# Ktzhdistid               : 1821
# Title                    : Kandidierende 1. Wahlgang Erneuerungswahl Ständerat 2015
# Description              : None
# Issued                   : 2021-06-01T13:01:26
# Modified                 : 2021-06-01T13:01:26
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001821.csv')

# Distribution 8
# Ktzhdistid               : 1696
# Title                    : Resultate 2. Wahlgang Erneuerungswahl Ständerat 2011
# Description              : None
# Issued                   : 2020-07-07T16:59:19
# Modified                 : 2021-06-01T13:00:21
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001696.csv')

# Distribution 9
# Ktzhdistid               : 1820
# Title                    : Kandidierende 2. Wahlgang Erneuerungswahl Ständerat 2011
# Description              : None
# Issued                   : 2021-06-01T13:00:38
# Modified                 : 2021-06-01T13:00:38
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001820.csv')

# Distribution 10
# Ktzhdistid               : 1695
# Title                    : Resultate 1. Wahlgang Erneuerungswahl Ständerat 2011
# Description              : None
# Issued                   : 2020-07-07T16:59:00
# Modified                 : 2021-06-01T12:58:49
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001695.csv')

# Distribution 11
# Ktzhdistid               : 1819
# Title                    : Kandidierende 1. Wahlgang Erneuerungswahl Ständerat 2011
# Description              : None
# Issued                   : 2021-06-01T12:59:42
# Modified                 : 2021-06-01T12:59:42
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001819.csv')

# Distribution 12
# Ktzhdistid               : 1694
# Title                    : Resultate 2. Wahlgang Erneuerungswahl Ständerat 2007
# Description              : None
# Issued                   : 2020-07-07T16:58:36
# Modified                 : 2021-06-01T10:47:23
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001694.csv')

# Distribution 13
# Ktzhdistid               : 1818
# Title                    : Kandidierende 2. Wahlgang Erneuerungswahl Ständerat 2007
# Description              : None
# Issued                   : 2021-06-01T10:59:23
# Modified                 : 2021-06-01T10:59:23
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001818.csv')

# Distribution 14
# Ktzhdistid               : 1693
# Title                    : Resultate 1. Wahlgang Erneuerungswahl Ständerat 2007
# Description              : None
# Issued                   : 2020-07-07T16:58:17
# Modified                 : 2021-06-01T10:46:20
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001693.csv')

# Distribution 15
# Ktzhdistid               : 1817
# Title                    : Kandidierende 1. Wahlgang Erneuerungswahl Ständerat 2007
# Description              : None
# Issued                   : 2021-06-01T10:46:51
# Modified                 : 2021-06-01T10:46:51
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001817.csv')

# Distribution 16
# Ktzhdistid               : 1692
# Title                    : Resultate 1. Wahlgang Erneuerungswahl Ständerat 2003
# Description              : None
# Issued                   : 2020-07-07T16:57:41
# Modified                 : 2021-06-01T10:45:59
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001692.csv')

# Distribution 17
# Ktzhdistid               : 1816
# Title                    : Kandidierende 1. Wahlgang Erneuerungswahl Ständerat 2003
# Description              : None
# Issued                   : 2021-06-01T10:43:02
# Modified                 : 2021-06-01T10:46:09
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000695_00001816.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch
