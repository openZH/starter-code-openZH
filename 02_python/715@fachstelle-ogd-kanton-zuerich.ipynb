# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Auto-generated Python starter code for dataset with identifier* **715@fachstelle-ogd-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Web Analytics der Open Government Data des Kantons Zürich auf opendata.swiss von Februar 2018 bis Februar 2021**

# %% [markdown]
# ## Description
#
# Monatliche Nutzungsstatistiken (Anzahl Besuche) der Open Government Data (OGD) Metadatensätze von Verwaltungseinheiten und Organen des Kantons Zürich, die auf dem zentralen Katalog für offene Behördendaten opendata.swiss findbar sind. Hinweise: Ab Januar 2019 sind die Web Analytics um weitere Metadateninformationen erweitert bzw. wurden Metadatenanpassungen vorgenommen. Ab März 2021 sind die monatlichen Aktualisierungen aufgrund technischer Herausforderungen pausiert. Variabelndefinitionen: Column 'name' = dataset slug; 'issued' = first publication of dataset; 'organization_name' = publisher slug; 'organization_url' = publisher URL; 'E' up to 'AB' = thematic categories according to DCAT AP Switzerland.

# %% [markdown]
# ## Dataset links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/statistik-daten/datenkatalog.html#/datasets/715@fachstelle-ogd-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2018-12-10T23:00:00`
# - **Modified** `2023-05-24T22:00:00`
# - **Startdate** `2018-02-01`
# - **Enddate** `2021-03-28`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/ECON', 'http://publications.europa.eu/resource/authority/data-theme/GOVE']`
# - **Keyword** `['kanton_zuerich', 'kantonale_verwaltung', 'ogd']`
# - **Publisher** `['Fachstelle Open Government Data des Kantons Zürich']`
# - **Landingpage** `nan`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'CSV' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`37` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1630
# Title                    : ZH Datasets Visits - 2020 Februar
# Description              : None
# Issued                   : 2020-04-22T22:00:00
# Modified                 : 2020-04-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001630.csv')

# Distribution 1
# Ktzhdistid               : 1629
# Title                    : ZH Datasets Visits - 2020 Januar
# Description              : None
# Issued                   : 2020-04-22T22:00:00
# Modified                 : 2020-04-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001629.csv')

# Distribution 2
# Ktzhdistid               : 1631
# Title                    : ZH Datasets Visits - 2020 März
# Description              : None
# Issued                   : 2020-04-22T22:00:00
# Modified                 : 2020-04-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001631.csv')

# Distribution 3
# Ktzhdistid               : 1708
# Title                    : ZH Datasets Visits - 2020 April
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001708.csv')

# Distribution 4
# Ktzhdistid               : 1709
# Title                    : ZH Datasets Visits - 2020 Mai
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001709.csv')

# Distribution 5
# Ktzhdistid               : 1710
# Title                    : ZH Datasets Visits - 2020 Juni
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001710.csv')

# Distribution 6
# Ktzhdistid               : 1730
# Title                    : ZH Datasets Visits - 2020 September
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-09-30T22:00:00
# Modified                 : 2020-09-30T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001730.csv')

# Distribution 7
# Ktzhdistid               : 770
# Title                    : ZH Datasets Visits - 2018 Februar
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000770.csv')

# Distribution 8
# Ktzhdistid               : 771
# Title                    : ZH Datasets Visits - 2018 März
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000771.csv')

# Distribution 9
# Ktzhdistid               : 772
# Title                    : ZH Datasets Visits - 2018 April
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000772.csv')

# Distribution 10
# Ktzhdistid               : 773
# Title                    : ZH Datasets Visits - 2018 Mai
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000773.csv')

# Distribution 11
# Ktzhdistid               : 774
# Title                    : ZH Datasets Visits - 2018 Juni
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000774.csv')

# Distribution 12
# Ktzhdistid               : 775
# Title                    : ZH Datasets Visits - 2018 Juli
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000775.csv')

# Distribution 13
# Ktzhdistid               : 776
# Title                    : ZH Datasets Visits - 2018 August
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000776.csv')

# Distribution 14
# Ktzhdistid               : 777
# Title                    : ZH Datasets Visits - 2018 September
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000777.csv')

# Distribution 15
# Ktzhdistid               : 778
# Title                    : ZH Datasets Visits - 2018 Oktober
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000778.csv')

# Distribution 16
# Ktzhdistid               : 779
# Title                    : ZH Datasets Visits - 2018 November
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000779.csv')

# Distribution 17
# Ktzhdistid               : 780
# Title                    : ZH Datasets Visits - 2018 Dezember
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000780.csv')

# Distribution 18
# Ktzhdistid               : 781
# Title                    : ZH Datasets Visits - 2019 Januar
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000781.csv')

# Distribution 19
# Ktzhdistid               : 782
# Title                    : ZH Datasets Visits - 2019 Februar
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000782.csv')

# Distribution 20
# Ktzhdistid               : 783
# Title                    : ZH Datasets Visits - 2019 März
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000783.csv')

# Distribution 21
# Ktzhdistid               : 784
# Title                    : ZH Datasets Visits - 2019 April
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000784.csv')

# Distribution 22
# Ktzhdistid               : 785
# Title                    : ZH Datasets Visits - 2019 Mai
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000785.csv')

# Distribution 23
# Ktzhdistid               : 835
# Title                    : ZH Datasets Visits - 2019 Juni
# Description              : None
# Issued                   : 2019-09-04T22:00:00
# Modified                 : 2019-09-04T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000835.csv')

# Distribution 24
# Ktzhdistid               : 836
# Title                    : ZH Datasets Visits - 2019 Juli
# Description              : None
# Issued                   : 2019-09-04T22:00:00
# Modified                 : 2019-09-04T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000836.csv')

# Distribution 25
# Ktzhdistid               : 837
# Title                    : ZH Datasets Visits - 2019 August
# Description              : None
# Issued                   : 2019-09-04T22:00:00
# Modified                 : 2019-09-04T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000837.csv')

# Distribution 26
# Ktzhdistid               : 848
# Title                    : ZH Datasets Visits - 2019 September
# Description              : None
# Issued                   : 2019-10-13T22:00:00
# Modified                 : 2019-10-13T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000848.csv')

# Distribution 27
# Ktzhdistid               : 908
# Title                    : ZH Datasets Visits - 2019 Oktober
# Description              : None
# Issued                   : 2019-11-03T23:00:00
# Modified                 : 2019-11-03T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000908.csv')

# Distribution 28
# Ktzhdistid               : 1088
# Title                    : ZH Datasets Visits - 2019 November
# Description              : None
# Issued                   : 2019-12-15T23:00:00
# Modified                 : 2019-12-15T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001088.csv')

# Distribution 29
# Ktzhdistid               : 1128
# Title                    : ZH Datasets Visits - 2019 Dezember
# Description              : None
# Issued                   : 2020-01-12T23:00:00
# Modified                 : 2020-01-12T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001128.csv')

# Distribution 30
# Ktzhdistid               : 1711
# Title                    : ZH Datasets Visits - 2020 Juli
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001711.csv')

# Distribution 31
# Ktzhdistid               : 1720
# Title                    : ZH Datasets Visits - 2020 August
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-31T22:00:00
# Modified                 : 2020-08-31T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001720.csv')

# Distribution 32
# Ktzhdistid               : 1752
# Title                    : ZH Datasets Visits - 2020 Oktober
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-11-12T23:00:00
# Modified                 : 2020-11-12T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001752.csv')

# Distribution 33
# Ktzhdistid               : 1772
# Title                    : ZH Datasets Visits - 2020 November
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-12-01T23:00:00
# Modified                 : 2020-12-01T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001772.csv')

# Distribution 34
# Ktzhdistid               : 1799
# Title                    : ZH Datasets Visits - 2021 Februar
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kanton Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2021-03-23T23:00:00
# Modified                 : 2021-03-23T23:00:00

df = get_dataset('https://raw.githubusercontent.com/openZH/web-analytics-der-open-government-data-des-kantons-zuerich/master/data/ZH_Datasets_UniqueActions_2021-02.csv')

# Distribution 35
# Ktzhdistid               : 1798
# Title                    : ZH Datasets Visits - 2021 Januar
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2021-03-23T23:00:00
# Modified                 : 2021-03-23T23:00:00

df = get_dataset('https://raw.githubusercontent.com/openZH/web-analytics-der-open-government-data-des-kantons-zuerich/master/data/ZH_Datasets_UniqueActions_2021-01.csv')

# Distribution 36
# Ktzhdistid               : 1797
# Title                    : ZH Datasets Visits - 2020 Dezember
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2021-03-23T23:00:00
# Modified                 : 2021-03-23T23:00:00

df = get_dataset('https://raw.githubusercontent.com/openZH/web-analytics-der-open-government-data-des-kantons-zuerich/master/data/ZH_Datasets_UniqueActions_2020-12.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except Exception:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except Exception:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except Exception:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Questions about the data?** Fachstelle Open Government Data des Kantons Zürich | info@open.zh.ch

# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Auto-generated Python starter code for dataset with identifier* **715@fachstelle-ogd-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Web Analytics der Open Government Data des Kantons Zürich auf opendata.swiss von Februar 2018 bis Februar 2021**

# %% [markdown]
# ## Description
#
# Monatliche Nutzungsstatistiken (Anzahl Besuche) der Open Government Data (OGD) Metadatensätze von Verwaltungseinheiten und Organen des Kantons Zürich, die auf dem zentralen Katalog für offene Behördendaten opendata.swiss findbar sind. Hinweise: Ab Januar 2019 sind die Web Analytics um weitere Metadateninformationen erweitert bzw. wurden Metadatenanpassungen vorgenommen. Ab März 2021 sind die monatlichen Aktualisierungen aufgrund technischer Herausforderungen pausiert. Variabelndefinitionen: Column 'name' = dataset slug; 'issued' = first publication of dataset; 'organization_name' = publisher slug; 'organization_url' = publisher URL; 'E' up to 'AB' = thematic categories according to DCAT AP Switzerland.

# %% [markdown]
# ## Dataset links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/statistik-daten/datenkatalog.html#/datasets/715@fachstelle-ogd-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2018-12-10T23:00:00`
# - **Modified** `2023-05-24T22:00:00`
# - **Startdate** `2018-02-01`
# - **Enddate** `2021-03-28`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/ECON', 'http://publications.europa.eu/resource/authority/data-theme/GOVE']`
# - **Keyword** `['kanton_zuerich', 'kantonale_verwaltung', 'ogd']`
# - **Publisher** `['Fachstelle Open Government Data des Kantons Zürich']`
# - **Landingpage** `nan`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'CSV' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`37` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 1630
# Title                    : ZH Datasets Visits - 2020 Februar
# Description              : None
# Issued                   : 2020-04-22T22:00:00
# Modified                 : 2020-04-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001630.csv')

# Distribution 1
# Ktzhdistid               : 1629
# Title                    : ZH Datasets Visits - 2020 Januar
# Description              : None
# Issued                   : 2020-04-22T22:00:00
# Modified                 : 2020-04-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001629.csv')

# Distribution 2
# Ktzhdistid               : 1631
# Title                    : ZH Datasets Visits - 2020 März
# Description              : None
# Issued                   : 2020-04-22T22:00:00
# Modified                 : 2020-04-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001631.csv')

# Distribution 3
# Ktzhdistid               : 1708
# Title                    : ZH Datasets Visits - 2020 April
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001708.csv')

# Distribution 4
# Ktzhdistid               : 1709
# Title                    : ZH Datasets Visits - 2020 Mai
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001709.csv')

# Distribution 5
# Ktzhdistid               : 1710
# Title                    : ZH Datasets Visits - 2020 Juni
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001710.csv')

# Distribution 6
# Ktzhdistid               : 1730
# Title                    : ZH Datasets Visits - 2020 September
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-09-30T22:00:00
# Modified                 : 2020-09-30T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001730.csv')

# Distribution 7
# Ktzhdistid               : 770
# Title                    : ZH Datasets Visits - 2018 Februar
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000770.csv')

# Distribution 8
# Ktzhdistid               : 771
# Title                    : ZH Datasets Visits - 2018 März
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000771.csv')

# Distribution 9
# Ktzhdistid               : 772
# Title                    : ZH Datasets Visits - 2018 April
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000772.csv')

# Distribution 10
# Ktzhdistid               : 773
# Title                    : ZH Datasets Visits - 2018 Mai
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000773.csv')

# Distribution 11
# Ktzhdistid               : 774
# Title                    : ZH Datasets Visits - 2018 Juni
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000774.csv')

# Distribution 12
# Ktzhdistid               : 775
# Title                    : ZH Datasets Visits - 2018 Juli
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000775.csv')

# Distribution 13
# Ktzhdistid               : 776
# Title                    : ZH Datasets Visits - 2018 August
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000776.csv')

# Distribution 14
# Ktzhdistid               : 777
# Title                    : ZH Datasets Visits - 2018 September
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000777.csv')

# Distribution 15
# Ktzhdistid               : 778
# Title                    : ZH Datasets Visits - 2018 Oktober
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000778.csv')

# Distribution 16
# Ktzhdistid               : 779
# Title                    : ZH Datasets Visits - 2018 November
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000779.csv')

# Distribution 17
# Ktzhdistid               : 780
# Title                    : ZH Datasets Visits - 2018 Dezember
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000780.csv')

# Distribution 18
# Ktzhdistid               : 781
# Title                    : ZH Datasets Visits - 2019 Januar
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000781.csv')

# Distribution 19
# Ktzhdistid               : 782
# Title                    : ZH Datasets Visits - 2019 Februar
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000782.csv')

# Distribution 20
# Ktzhdistid               : 783
# Title                    : ZH Datasets Visits - 2019 März
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000783.csv')

# Distribution 21
# Ktzhdistid               : 784
# Title                    : ZH Datasets Visits - 2019 April
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000784.csv')

# Distribution 22
# Ktzhdistid               : 785
# Title                    : ZH Datasets Visits - 2019 Mai
# Description              : None
# Issued                   : 2019-08-25T22:00:00
# Modified                 : 2019-08-25T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000785.csv')

# Distribution 23
# Ktzhdistid               : 835
# Title                    : ZH Datasets Visits - 2019 Juni
# Description              : None
# Issued                   : 2019-09-04T22:00:00
# Modified                 : 2019-09-04T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000835.csv')

# Distribution 24
# Ktzhdistid               : 836
# Title                    : ZH Datasets Visits - 2019 Juli
# Description              : None
# Issued                   : 2019-09-04T22:00:00
# Modified                 : 2019-09-04T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000836.csv')

# Distribution 25
# Ktzhdistid               : 837
# Title                    : ZH Datasets Visits - 2019 August
# Description              : None
# Issued                   : 2019-09-04T22:00:00
# Modified                 : 2019-09-04T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000837.csv')

# Distribution 26
# Ktzhdistid               : 848
# Title                    : ZH Datasets Visits - 2019 September
# Description              : None
# Issued                   : 2019-10-13T22:00:00
# Modified                 : 2019-10-13T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000848.csv')

# Distribution 27
# Ktzhdistid               : 908
# Title                    : ZH Datasets Visits - 2019 Oktober
# Description              : None
# Issued                   : 2019-11-03T23:00:00
# Modified                 : 2019-11-03T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00000908.csv')

# Distribution 28
# Ktzhdistid               : 1088
# Title                    : ZH Datasets Visits - 2019 November
# Description              : None
# Issued                   : 2019-12-15T23:00:00
# Modified                 : 2019-12-15T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001088.csv')

# Distribution 29
# Ktzhdistid               : 1128
# Title                    : ZH Datasets Visits - 2019 Dezember
# Description              : None
# Issued                   : 2020-01-12T23:00:00
# Modified                 : 2020-01-12T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001128.csv')

# Distribution 30
# Ktzhdistid               : 1711
# Title                    : ZH Datasets Visits - 2020 Juli
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-09T22:00:00
# Modified                 : 2020-08-09T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001711.csv')

# Distribution 31
# Ktzhdistid               : 1720
# Title                    : ZH Datasets Visits - 2020 August
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-08-31T22:00:00
# Modified                 : 2020-08-31T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001720.csv')

# Distribution 32
# Ktzhdistid               : 1752
# Title                    : ZH Datasets Visits - 2020 Oktober
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-11-12T23:00:00
# Modified                 : 2020-11-12T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001752.csv')

# Distribution 33
# Ktzhdistid               : 1772
# Title                    : ZH Datasets Visits - 2020 November
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2020-12-01T23:00:00
# Modified                 : 2020-12-01T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000715_00001772.csv')

# Distribution 34
# Ktzhdistid               : 1799
# Title                    : ZH Datasets Visits - 2021 Februar
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kanton Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2021-03-23T23:00:00
# Modified                 : 2021-03-23T23:00:00

df = get_dataset('https://raw.githubusercontent.com/openZH/web-analytics-der-open-government-data-des-kantons-zuerich/master/data/ZH_Datasets_UniqueActions_2021-02.csv')

# Distribution 35
# Ktzhdistid               : 1798
# Title                    : ZH Datasets Visits - 2021 Januar
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2021-03-23T23:00:00
# Modified                 : 2021-03-23T23:00:00

df = get_dataset('https://raw.githubusercontent.com/openZH/web-analytics-der-open-government-data-des-kantons-zuerich/master/data/ZH_Datasets_UniqueActions_2021-01.csv')

# Distribution 36
# Ktzhdistid               : 1797
# Title                    : ZH Datasets Visits - 2020 Dezember
# Description              : Ausgenommen sind die Datensätze, die von der Geoinformation des Kantons Zürich auf opendata.swiss verwaltet werden.
# Issued                   : 2021-03-23T23:00:00
# Modified                 : 2021-03-23T23:00:00

df = get_dataset('https://raw.githubusercontent.com/openZH/web-analytics-der-open-government-data-des-kantons-zuerich/master/data/ZH_Datasets_UniqueActions_2020-12.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Questions about the data?** Fachstelle Open Government Data des Kantons Zürich | info@open.zh.ch
