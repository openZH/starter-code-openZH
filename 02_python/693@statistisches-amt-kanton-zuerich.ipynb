# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Auto-generated Python starter code for dataset with identifier* **693@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Archiv Wahlresultate Nationalratswahlen**

# %% [markdown]
# ## Description
#
# Ergebnisse der Erneuerungswahlen der zürcherischen Mitglieder des Nationalrates

# %% [markdown]
# ## Dataset links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/statistik-daten/datenkatalog.html#/datasets/693@statistisches-amt-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2020-07-06T22:00:00`
# - **Modified** `2024-03-27T23:00:00`
# - **Startdate** `2007-10-21`
# - **Enddate** `2023-10-22`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/GOVE']`
# - **Keyword** `['demokratie', 'kanton_zuerich', 'nationalrat', 'nationalratswahlen', 'ogd', 'panaschierstimmen', 'politik', 'politische_parteien', 'wahlarchiv', 'wahlen', 'wahlergebnisse']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/national-staenderatswahlen.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'CSV' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`31` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 4844
# Title                    : Zuordnungstabelle Listen – Parteien
# Description              : Tabelle für die Zuordnung von Listen zu Parteien bei Nationalratswahlen im Kanton Zürich. Die ausgewiesenen Parteien sind an die vom Bundesamt für Statistik (BFS) in Zeitreihen separat ausgewiesenen Parteien angelehnt.
# Issued                   : 2023-11-21T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004844.csv')

# Distribution 1
# Ktzhdistid               : 1674
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2007
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2007 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001674.csv')

# Distribution 2
# Ktzhdistid               : 4952
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2007
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004952.csv')

# Distribution 3
# Ktzhdistid               : 4951
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2007
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004951.csv')

# Distribution 4
# Ktzhdistid               : 1833
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2007
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2007
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001833.csv')

# Distribution 5
# Ktzhdistid               : 1675
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2007
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2007
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001675.csv')

# Distribution 6
# Ktzhdistid               : 1676
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2007
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2007
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001676.csv')

# Distribution 7
# Ktzhdistid               : 1677
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2011
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2011 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001677.csv')

# Distribution 8
# Ktzhdistid               : 4950
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2011
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004950.csv')

# Distribution 9
# Ktzhdistid               : 4949
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2011
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004949.csv')

# Distribution 10
# Ktzhdistid               : 1834
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2011
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2011
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001834.csv')

# Distribution 11
# Ktzhdistid               : 1678
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2011
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2011
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001678.csv')

# Distribution 12
# Ktzhdistid               : 1679
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2011
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2011
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001679.csv')

# Distribution 13
# Ktzhdistid               : 1680
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2015
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2015 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001680.csv')

# Distribution 14
# Ktzhdistid               : 4948
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2015
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004948.csv')

# Distribution 15
# Ktzhdistid               : 4947
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2015
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004947.csv')

# Distribution 16
# Ktzhdistid               : 1835
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2015
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2015
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001835.csv')

# Distribution 17
# Ktzhdistid               : 1681
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2015
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2015
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-23T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001681.csv')

# Distribution 18
# Ktzhdistid               : 1682
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2015
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2015
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001682.csv')

# Distribution 19
# Ktzhdistid               : 1683
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2019
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2019 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001683.csv')

# Distribution 20
# Ktzhdistid               : 4946
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2019
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004946.csv')

# Distribution 21
# Ktzhdistid               : 4945
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2019
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004945.csv')

# Distribution 22
# Ktzhdistid               : 1836
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2019
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2019
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001836.csv')

# Distribution 23
# Ktzhdistid               : 1684
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2019
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2019
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-23T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001684.csv')

# Distribution 24
# Ktzhdistid               : 1685
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2019
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2019
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2025-02-02T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001685.csv')

# Distribution 25
# Ktzhdistid               : 4705
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2023
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2023 pro Gemeinde
# Issued                   : 2023-10-22T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004705.csv')

# Distribution 26
# Ktzhdistid               : 4944
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2023
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004944.csv')

# Distribution 27
# Ktzhdistid               : 4703
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2023
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2023
# Issued                   : 2023-10-22T22:00:00
# Modified                 : 2023-10-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004703.csv')

# Distribution 28
# Ktzhdistid               : 4943
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2023
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004943.csv')

# Distribution 29
# Ktzhdistid               : 4704
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2023
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2023
# Issued                   : 2023-10-22T22:00:00
# Modified                 : 2023-11-23T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004704.csv')

# Distribution 30
# Ktzhdistid               : 4523
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2023
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2023
# Issued                   : 2023-09-03T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004523.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except Exception:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except Exception:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except Exception:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch

# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Auto-generated Python starter code for dataset with identifier* **693@statistisches-amt-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Archiv Wahlresultate Nationalratswahlen**

# %% [markdown]
# ## Description
#
# Ergebnisse der Erneuerungswahlen der zürcherischen Mitglieder des Nationalrates

# %% [markdown]
# ## Dataset links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/statistik-daten/datenkatalog.html#/datasets/693@statistisches-amt-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2020-07-06T22:00:00`
# - **Modified** `2024-03-27T23:00:00`
# - **Startdate** `2007-10-21`
# - **Enddate** `2023-10-22`
# - **Theme** `['http://publications.europa.eu/resource/authority/data-theme/GOVE']`
# - **Keyword** `['demokratie', 'kanton_zuerich', 'nationalrat', 'nationalratswahlen', 'ogd', 'panaschierstimmen', 'politik', 'politische_parteien', 'wahlarchiv', 'wahlen', 'wahlergebnisse']`
# - **Publisher** `['Statistisches Amt des Kantons Zürich']`
# - **Landingpage** `https://www.zh.ch/de/politik-staat/wahlen-abstimmungen/national-staenderatswahlen.html`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# Helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The dataset URL has no proper 'CSV' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # If dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`31` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 4844
# Title                    : Zuordnungstabelle Listen – Parteien
# Description              : Tabelle für die Zuordnung von Listen zu Parteien bei Nationalratswahlen im Kanton Zürich. Die ausgewiesenen Parteien sind an die vom Bundesamt für Statistik (BFS) in Zeitreihen separat ausgewiesenen Parteien angelehnt.
# Issued                   : 2023-11-21T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004844.csv')

# Distribution 1
# Ktzhdistid               : 1674
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2007
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2007 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001674.csv')

# Distribution 2
# Ktzhdistid               : 4952
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2007
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004952.csv')

# Distribution 3
# Ktzhdistid               : 4951
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2007
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004951.csv')

# Distribution 4
# Ktzhdistid               : 1833
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2007
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2007
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001833.csv')

# Distribution 5
# Ktzhdistid               : 1675
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2007
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2007
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001675.csv')

# Distribution 6
# Ktzhdistid               : 1676
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2007
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2007
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001676.csv')

# Distribution 7
# Ktzhdistid               : 1677
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2011
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2011 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001677.csv')

# Distribution 8
# Ktzhdistid               : 4950
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2011
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004950.csv')

# Distribution 9
# Ktzhdistid               : 4949
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2011
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004949.csv')

# Distribution 10
# Ktzhdistid               : 1834
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2011
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2011
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001834.csv')

# Distribution 11
# Ktzhdistid               : 1678
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2011
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2011
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001678.csv')

# Distribution 12
# Ktzhdistid               : 1679
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2011
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2011
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001679.csv')

# Distribution 13
# Ktzhdistid               : 1680
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2015
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2015 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001680.csv')

# Distribution 14
# Ktzhdistid               : 4948
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2015
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004948.csv')

# Distribution 15
# Ktzhdistid               : 4947
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2015
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004947.csv')

# Distribution 16
# Ktzhdistid               : 1835
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2015
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2015
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001835.csv')

# Distribution 17
# Ktzhdistid               : 1681
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2015
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2015
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-23T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001681.csv')

# Distribution 18
# Ktzhdistid               : 1682
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2015
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2015
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001682.csv')

# Distribution 19
# Ktzhdistid               : 1683
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2019
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2019 pro Gemeinde
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001683.csv')

# Distribution 20
# Ktzhdistid               : 4946
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2019
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004946.csv')

# Distribution 21
# Ktzhdistid               : 4945
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2019
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004945.csv')

# Distribution 22
# Ktzhdistid               : 1836
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2019
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2019
# Issued                   : 2021-06-01T22:00:00
# Modified                 : 2021-06-01T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001836.csv')

# Distribution 23
# Ktzhdistid               : 1684
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2019
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2019
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2023-11-23T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001684.csv')

# Distribution 24
# Ktzhdistid               : 1685
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2019
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2019
# Issued                   : 2020-07-06T22:00:00
# Modified                 : 2025-02-02T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00001685.csv')

# Distribution 25
# Ktzhdistid               : 4705
# Title                    : Panaschierstatistik Erneuerungswahl Nationalrat 2023
# Description              : Stimmen nach Herkunft für alle Kandidierenden der Nationalratswahl 2023 pro Gemeinde
# Issued                   : 2023-10-22T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004705.csv')

# Distribution 26
# Ktzhdistid               : 4944
# Title                    : Listenresultate Erneuerungswahl Nationalrat 2023
# Description              : Anzahl erhaltener Stimmen pro Liste und Gebiet
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004944.csv')

# Distribution 27
# Ktzhdistid               : 4703
# Title                    : Kandidierende Erneuerungswahl Nationalrat 2023
# Description              : Informationen zu den Kandidierenden der Nationalratswahl 2023
# Issued                   : 2023-10-22T22:00:00
# Modified                 : 2023-10-22T22:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004703.csv')

# Distribution 28
# Ktzhdistid               : 4943
# Title                    : Parteiresultate Erneuerungswahl Nationalrat 2023
# Description              : Anzahl erhaltener Stimmen pro Partei und Gebiet. Die Zuteilung der Listen zu einer Partei erfolgt gemäss der Ressource "Zuordnungstabelle Listen – Parteien" dieses Datasets.
# Issued                   : 2023-11-28T23:00:00
# Modified                 : 2023-11-28T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004943.csv')

# Distribution 29
# Ktzhdistid               : 4704
# Title                    : Gemeindeinformationen Erneuerungswahl Nationalrat 2023
# Description              : Gemeindespezifische Informationen wie BFS-Nummer und Stimmbeteiligung für die Nationalratswahl 2023
# Issued                   : 2023-10-22T22:00:00
# Modified                 : 2023-11-23T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004704.csv')

# Distribution 30
# Ktzhdistid               : 4523
# Title                    : Listenverbindungen Erneuerungswahl Nationalrat 2023
# Description              : Listenverbindungen und Unterlistenverbindungen der Nationalratswahl 2023
# Issued                   : 2023-09-03T22:00:00
# Modified                 : 2023-11-21T23:00:00

df = get_dataset('https://daten.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00000693_00004523.csv')

# %% [markdown]
# ## Analyze data

# %%
# Drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# Display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# Describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# Describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numerical data in dataset.")

# %%
# Check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# Plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numerical data to plot.")

# %%
# Continue your code here...

# %% [markdown]
# **Questions about the data?** Statistisches Amt des Kantons Zürich | Wahlen & Abstimmungen | wahlen@statistik.ji.zh.ch
