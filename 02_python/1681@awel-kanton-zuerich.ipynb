# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Autogenerated Python starter code for data set with identifier* **1681@awel-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Produktion von Wärme und Strom aus erneuerbaren Energieträgern im Kanton Zürich ab 2010**

# %% [markdown]
# ## Description
#
# Die Daten weisen für die verschiedenen erneuerbaren Energieträger aus, wie viel sie seit 2010 insgesamt pro Jahr in Megawattstunden (MWh) zur Produktion von Wärme und Strom beigetragen haben. Die Daten stammen aus der Markterhebung Sonnenenergie vom Bundesamt für Energie (BFE), für Biomasse (einschliesslich Holz) von der UMWEKO GmbH, für Abwasser von den Elektrizitätswerken des Kantons Zürich (EKZ) sowie vom Elektrizitätswerk der Stadt Zürich (EWZ), für Kehricht, für Wasser und für Luft vom Amt für Abfall, Wasser, Energie und Luft (AWEL) des Kantons Zürich. Hinweise: Die Biomasse-Daten zur Produktion von Wärme sind erst ab 2015 verfügbar. Zur Produktion von Strom mittels Geothermie (tiefe Bohrungen) und Windkraft gibt es im Kanton Zürich aktuell keine oder nur sehr tiefe Werte; beide Energieträger sind als Stromquellen in den Daten bis 2020 mit dem Wert '0' enthalten.

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.html#/datasets/1681@awel-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2022-08-25T09:41:42`
# - **Modified** `2022-08-25T10:36:57`
# - **Startdate** `2010-01-01`
# - **Enddate** `2020-12-31`
# - **Theme** `['Energie', None]`
# - **Keyword** `['abfall', 'elektrizitaet', 'elektrizitaetsproduktion', 'energie', 'energieproduktion', 'energietraeger', 'erneuerbare_energien', 'holz', 'kehricht', 'luft', 'seen', 'sonnenenergie', 'sonnenkollektor', 'strom', 'waermepumpen', 'wasser', 'wasserkraft', 'windenergie', 'grundwasser', 'energieressourcen', 'biomasse', 'geothermie', 'abwasser', 'waerme', 'photovoltaik', 'wind', 'windkraft', 'sonne', 'ogd']`
# - **Publisher** `['Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 3140
# Title                    : Produktion von Wärme und Strom aus erneuerbaren Energieträgern im Kanton Zürich
# Description              : Zur Produktion von Wärme in Megawattstunden (MWh) enthalten sind die Energieträger: Kehricht, Biomasse (einschliesslich Holz), Sonne, Wasser (umfasst Oberflächen- und Grundwasser), Geothermie (untiefe Bohrungen), Luft (umfasst Luft-Wärmepumpen) sowie Abwasser. Zur Produktion von Strom zusätzlich enthalten ist der Energieträger 'Windkraft', während bei 'Geothermie' keine 'untiefen', sondern nur 'tiefe' Bohrungen zur Stromproduktion beitragen; die Energieträger 'Luft' und 'Abwasser' werden zur Stromproduktion nicht genutzt.
# Issued                   : 2022-08-25T09:41:42
# Modified                 : 2022-08-25T09:41:42
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001681_00003140.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Amt für Abfall, Wasser, Energie und Luft des Kantons Zürich | Abteilung Energie | mirjam.baumann@bd.zh.ch
