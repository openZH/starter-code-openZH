# %% [markdown]
# ## Open Government Data, provided by **Canton Zurich**
# *Autogenerated Python starter code for data set with identifier* **1401@finanzverwaltung-kanton-zuerich**

# %% [markdown]
# ## Dataset
# # **Staatsquote des Kantons Zürich**

# %% [markdown]
# ## Description
#
# Die Staatsquote entspricht den «konsolidierten Gesamtausgaben» in Prozent des kantonalen Bruttoinlandprodukts (BIP). Die «konsolidierten Gesamtausgaben» umfassen die Ausgaben (Aufwand ohne Abschreibungen, Einlagen in Bestandeskonti von Fonds im Eigen- und Fremdkapital, durchlaufende Beiträge und interne Verrechnungen) plus Bruttoinvestitionen. Die konsolidierten Gesamtausgaben werden durch die Eidgenössischen Finanzverwaltung (EFV) berechnet. Das BIP des Kantons Zürich wird vom Bundesamt für Statistik (BFS) berechnet. Beide Wirtschaftsindikatoren werden mit einer zeitlichen Verzögerung von zwei Jahren veröffentlicht. Vorliegend wird die Staatsquote des Kantons ohne Gemeinden ausgewiesen. Für die interkantonale Vergleichbarkeit müsste die Staatsquote des Kantons und seiner Gemeinden betrachtet werden, aufgrund der je nach Kanton unterschiedlichen Aufgabenteilungen zwischen Kanton und Gemeinden.

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://www.zh.ch/de/politik-staat/opendata.html#/datasets/1401@finanzverwaltung-kanton-zuerich)

# %% [markdown]
# ## Metadata
# - **Issued** `2022-06-07T11:05:44`
# - **Modified** `2023-01-26T14:12:38`
# - **Startdate** `2008-12-31`
# - **Enddate** `2020-12-31`
# - **Theme** `['Öffentliche Verwaltung und Finanzen']`
# - **Keyword** `['finanzkennzahlen', 'oeffentliche_finanzen', 'staatsfinanzen', 'ogd']`
# - **Publisher** `['Finanzverwaltung des Kantons Zürich']`
# - **Landingpage** `None`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    if url[-3:] != "csv":
        print("The data set URL has no proper 'csv' extension. Reading the dataset might not have worked as expected.\nPlease check the dataset link and adjust pandas' read_csv() parameters accordingly.")
    data = pd.read_csv(url, sep=",", on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not comma separated, use ";" instead
    if data.shape[1] <= 1:
        data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
        if data.shape[1] <= 1:
            print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# - The dataset has **`1` distribution(s)** in CSV format.
# - All available CSV distributions are listed below and can be read into a pandas dataframe.

# %%
# Distribution 0
# Ktzhdistid               : 2738
# Title                    : Staatsquote des Kantons Zürich ab 2008
# Description              : Variabeln: 'gesamtausgaben' und 'bruttoinlandprodukt' in Tausend CHF.
# Issued                   : 2022-06-07T11:05:44
# Modified                 : 2023-01-26T14:12:03
# Rights                   : NonCommercialAllowed-CommercialAllowed-ReferenceRequired

df = get_dataset('https://www.web.statistik.zh.ch/ogd/daten/ressourcen/KTZH_00001401_00002738.csv')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Finanzverwaltung des Kantons Zürich | Steuerung Finanzhaushalt | finanzhaushalt@fdfv.zh.ch
